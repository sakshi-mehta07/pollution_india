# %%
# Import relevant libraries
import requests
import pandas as pd
import os
import json
import requests
from bs4 import BeautifulSoup
from unidecode import unidecode

# %%
city_dict = {'arunachal pradesh': ['naharlagun'],
 'jammu and kashmir': ['srinagar'],
 'andhra pradesh': ['chittoor',
  'kadapa',
  'anantapur',
  'visakhapatnam',
  'amaravati',
  'vijayawada',
  'rajamahendravaram',
  'tirupati'],
 'telangana': ['hyderabad'],
 'manipur': ['imphal'],
 'madhya pradesh': ['mandideep',
  'satna',
  'bhopal',
  'ratlam',
  'gwalior',
  'katni',
  'maihar',
  'damoh',
  'dewas',
  'jabalpur',
  'ujjain',
  'sagar',
  'singrauli',
  'pithampur',
  'indore'],
 'haryana': ['ambala',
  'sirsa',
  'palwal',
  'kurukshetra',
  'ballabgarh',
  'manesar',
  'narnaul',
  'gurugram',
  'karnal',
  'bahadurgarh',
  'rohtak',
  'kaithal',
  'sonipat',
  'mandikhera',
  'faridabad',
  'hisar',
  'yamunanagar',
  'charkhi_dadri',
  'jind',
  'panipat',
  'bhiwani',
  'panchkula',
  'fatehabad',
  'dharuhera'],
 'gujarat': ['ankleshwar',
  'gandhinagar',
  'surat',
  'vapi',
  'vatva',
  'ahmedabad',
  'nandesari'],
 'sikkim': ['gangtok'],
 'himachal pradesh': ['baddi'],
 'delhi': ['delhi'],
 'punjab': ['ludhiana',
  'bathinda',
  'mandi_gobindgarh',
  'khanna',
  'rupnagar',
  'jalandhar',
  'amritsar',
  'patiala'],
 'karnataka': ['mysuru',
  'yadgir',
  'kolar',
  'koppal',
  'bidar',
  'vijayapura',
  'gadag',
  'mangalore',
  'kalaburagi',
  'hubballi',
  'udupi',
  'belgaum',
  'madikeri',
  'haveri',
  'tumakuru',
  'bengaluru',
  'dharwad',
  'hassan',
  'shivamogga',
  'chikkamagaluru',
  'chamarajanagar',
  'chikkaballapur',
  'bagalkot',
  'davanagere',
  'ramanagara',
  'raichur',
  'karwar'],
 'maharashtra': ['latur',
  'kalyan',
  'sangli',
  'dhule',
  'bhiwandi',
  'virar',
  'kolhapur',
  'nagpur',
  'chandrapur',
  'pune',
  'jalgaon',
  'solapur',
  'ulhasnagar',
  'amravati',
  'parbhani',
  'badlapur',
  'akola',
  'boisar',
  'mumbai',
  'jalna',
  'nashik',
  'belapur',
  'malegaon',
  'thane',
  'navi_mumbai',
  'mahad',
  'nanded'],
 'odisha': ['baripada',
  'bileipada',
  'angul',
  'tensa',
  'cuttack',
  'balasore',
  'keonjhar',
  'rairangpur',
  'talcher',
  'byasanagar',
  'suakati',
  'rourkela',
  'nayagarh',
  'barbil',
  'brajrajnagar'],
 'rajasthan': ['sirohi',
  'baran',
  'banswara',
  'hanumangarh',
  'bharatpur',
  'bikaner',
  'jalore',
  'bhiwadi',
  'sikar',
  'karauli',
  'bhilwara',
  'alwar',
  'bundi',
  'dausa',
  'chittorgarh',
  'barmer',
  'jaipur',
  'jaisalmer',
  'pratapgarh',
  'sawai_madhopur',
  'jhalawar',
  'jhunjhunu',
  'nagaur',
  'ajmer',
  'rajsamand',
  'jodhpur',
  'sri_ganganagar',
  'pali',
  'kota',
  'dholpur',
  'dungarpur',
  'tonk',
  'churu',
  'udaipur'],
 'chandigarh': ['chandigarh'],
 'kerala': ['thiruvananthapuram',
  'thrissur',
  'kozhikode',
  'kollam',
  'kannur',
  'eloor',
  'ernakulam',
  'kochi'],
 'chhattisgarh': ['bhilai',
  'chhal',
  'milupara',
  'bilaspur',
  'raipur',
  'tumidih',
  'kunjemura',
  'korba'],
 'tripura': [],
 'mizoram': ['aizawl'],
 'assam': ['silchar',
  'nalbari',
  'guwahati',
  'nagaon',
  'sivasagar',
  'byrnihat'],
 'meghalaya': ['shillong'],
 'tamil nadu': ['tiruchirappalli',
  'nagapattinam',
  'coimbatore',
  'vellore',
  'ranipet',
  'dindigul',
  'tirupur',
  'ooty',
  'kanchipuram',
  'tirunelveli',
  'chennai',
  'gummidipoondi',
  'perundurai',
  'thanjavur',
  'cuddalore',
  'karur',
  'thoothukudi',
  'pudukottai',
  'ariyalur',
  'salem',
  'madurai',
  'ramanathapuram',
  'virudhunagar',
  'hosur',
  'palkalaiperur',
  'chengalpattu'],
 'west bengal': ['kolkata',
  'haldia',
  'durgapur',
  'siliguri',
  'asansol',
  'howrah',
  'barrackpore'],
 'uttarakhand': ['kashipur', 'rishikesh', 'dehradun'],
 'uttar pradesh': ['agra',
  'prayagraj',
  'meerut',
  'jhansi',
  'greater_noida',
  'kanpur',
  'bulandshahr',
  'lucknow',
  'firozabad',
  'moradabad',
  'hapur',
  'vrindavan',
  'ghaziabad',
  'bareilly',
  'noida',
  'varanasi',
  'muzaffarnagar',
  'gorakhpur',
  'khurja',
  'baghpat'],
 'puducherry': ['puducherry'],
 'bihar': ['rajgir',
  'araria',
  'bettiah',
  'begusarai',
  'katihar',
  'saharsa',
  'samastipur',
  'motihari',
  'muzaffarpur',
  'bhagalpur',
  'buxar',
  'darbhanga',
  'sasaram',
  'bihar_sharif',
  'purnia',
  'manguraha',
  'patna',
  'arrah',
  'hajipur',
  'siwan',
  'chhapra',
  'kishanganj',
  'munger',
  'gaya'],
 'jharkhand': ['dhanbad', 'jorapokhar', 'pathardih'],
 'nagaland': ['kohima']}


state_list = list(city_dict.keys())
print(state_list)
c_list = list(city_dict.values())
city_list = []
for inner_list in c_list:
    city_list.extend(inner_list)
    
# Checking duplicate city names
display(city_list)
print(len(set(city_list)))

# Number of states
print(len(state_list))
# Out:
# ['arunachal pradesh', 'jammu and kashmir', 'andhra pradesh', 'telangana', 'manipur', 'madhya pradesh', 'haryana', 'gujarat', 'sikkim', 'himachal pradesh', 'delhi', 'punjab', 'karnataka', 'maharashtra', 'odisha', 'rajasthan', 'chandigarh', 'kerala', 'chhattisgarh', 'tripura', 'mizoram', 'assam', 'meghalaya', 'tamil nadu', 'west bengal', 'uttarakhand', 'uttar pradesh', 'puducherry', 'bihar', 'jharkhand', 'nagaland']
# ['naharlagun',
#  'srinagar',
#  'chittoor',
#  'kadapa',
#  'anantapur',
#  'visakhapatnam',
#  'amaravati',
#  'vijayawada',
#  'rajamahendravaram',
#  'tirupati',
#  'hyderabad',
#  'imphal',
#  'mandideep',
#  'satna',
#  'bhopal',
#  'ratlam',
#  'gwalior',
#  'katni',
#  'maihar',
#  'damoh',
#  'dewas',
#  'jabalpur',
#  'ujjain',
#  'sagar',
#  'singrauli',
#  'pithampur',
#  'indore',
#  'ambala',
#  'sirsa',
#  'palwal',
#  'kurukshetra',
#  'ballabgarh',
#  'manesar',
#  'narnaul',
#  'gurugram',
#  'karnal',
#  'bahadurgarh',
#  'rohtak',
#  'kaithal',
#  'sonipat',
#  'mandikhera',
#  'faridabad',
#  'hisar',
#  'yamunanagar',
#  'charkhi_dadri',
#  'jind',
#  'panipat',
#  'bhiwani',
#  'panchkula',
#  'fatehabad',
#  'dharuhera',
#  'ankleshwar',
#  'gandhinagar',
#  'surat',
#  'vapi',
#  'vatva',
#  'ahmedabad',
#  'nandesari',
#  'gangtok',
#  'baddi',
#  'delhi',
#  'ludhiana',
#  'bathinda',
#  'mandi_gobindgarh',
#  'khanna',
#  'rupnagar',
#  'jalandhar',
#  'amritsar',
#  'patiala',
#  'mysuru',
#  'yadgir',
#  'kolar',
#  'koppal',
#  'bidar',
#  'vijayapura',
#  'gadag',
#  'mangalore',
#  'kalaburagi',
#  'hubballi',
#  'udupi',
#  'belgaum',
#  'madikeri',
#  'haveri',
#  'tumakuru',
#  'bengaluru',
#  'dharwad',
#  'hassan',
#  'shivamogga',
#  'chikkamagaluru',
#  'chamarajanagar',
#  'chikkaballapur',
#  'bagalkot',
#  'davanagere',
#  'ramanagara',
#  'raichur',
#  'karwar',
#  'latur',
#  'kalyan',
#  'sangli',
#  'dhule',
#  'bhiwandi',
#  'virar',
#  'kolhapur',
#  'nagpur',
#  'chandrapur',
#  'pune',
#  'jalgaon',
#  'solapur',
#  'ulhasnagar',
#  'amravati',
#  'parbhani',
#  'badlapur',
#  'akola',
#  'boisar',
#  'mumbai',
#  'jalna',
#  'nashik',
#  'belapur',
#  'malegaon',
#  'thane',
#  'navi_mumbai',
#  'mahad',
#  'nanded',
#  'baripada',
#  'bileipada',
#  'angul',
#  'tensa',
#  'cuttack',
#  'balasore',
#  'keonjhar',
#  'rairangpur',
#  'talcher',
#  'byasanagar',
#  'suakati',
#  'rourkela',
#  'nayagarh',
#  'barbil',
#  'brajrajnagar',
#  'sirohi',
#  'baran',
#  'banswara',
#  'hanumangarh',
#  'bharatpur',
#  'bikaner',
#  'jalore',
#  'bhiwadi',
#  'sikar',
#  'karauli',
#  'bhilwara',
#  'alwar',
#  'bundi',
#  'dausa',
#  'chittorgarh',
#  'barmer',
#  'jaipur',
#  'jaisalmer',
#  'pratapgarh',
#  'sawai_madhopur',
#  'jhalawar',
#  'jhunjhunu',
#  'nagaur',
#  'ajmer',
#  'rajsamand',
#  'jodhpur',
#  'sri_ganganagar',
#  'pali',
#  'kota',
#  'dholpur',
#  'dungarpur',
#  'tonk',
#  'churu',
#  'udaipur',
#  'chandigarh',
#  'thiruvananthapuram',
#  'thrissur',
#  'kozhikode',
#  'kollam',
#  'kannur',
#  'eloor',
#  'ernakulam',
#  'kochi',
#  'bhilai',
#  'chhal',
#  'milupara',
#  'bilaspur',
#  'raipur',
#  'tumidih',
#  'kunjemura',
#  'korba',
#  'aizawl',
#  'silchar',
#  'nalbari',
#  'guwahati',
#  'nagaon',
#  'sivasagar',
#  'byrnihat',
#  'shillong',
#  'tiruchirappalli',
#  'nagapattinam',
#  'coimbatore',
#  'vellore',
#  'ranipet',
#  'dindigul',
#  'tirupur',
#  'ooty',
#  'kanchipuram',
#  'tirunelveli',
#  'chennai',
#  'gummidipoondi',
#  'perundurai',
#  'thanjavur',
#  'cuddalore',
#  'karur',
#  'thoothukudi',
#  'pudukottai',
#  'ariyalur',
#  'salem',
#  'madurai',
#  'ramanathapuram',
#  'virudhunagar',
#  'hosur',
#  'palkalaiperur',
#  'chengalpattu',
#  'kolkata',
#  'haldia',
#  'durgapur',
#  'siliguri',
#  'asansol',
#  'howrah',
#  'barrackpore',
#  'kashipur',
#  'rishikesh',
#  'dehradun',
#  'agra',
#  'prayagraj',
#  'meerut',
#  'jhansi',
#  'greater_noida',
#  'kanpur',
#  'bulandshahr',
#  'lucknow',
#  'firozabad',
#  'moradabad',
#  'hapur',
#  'vrindavan',
#  'ghaziabad',
#  'bareilly',
#  'noida',
#  'varanasi',
#  'muzaffarnagar',
#  'gorakhpur',
#  'khurja',
#  'baghpat',
#  'puducherry',
#  'rajgir',
#  'araria',
#  'bettiah',
#  'begusarai',
#  'katihar',
#  'saharsa',
#  'samastipur',
#  'motihari',
#  'muzaffarpur',
#  'bhagalpur',
#  'buxar',
#  'darbhanga',
#  'sasaram',
#  'bihar_sharif',
#  'purnia',
#  'manguraha',
#  'patna',
#  'arrah',
#  'hajipur',
#  'siwan',
#  'chhapra',
#  'kishanganj',
#  'munger',
#  'gaya',
#  'dhanbad',
#  'jorapokhar',
#  'pathardih',
#  'kohima']
# 282
# 31

# %%
# Try to access the website
url = "https://en.wikipedia.org/wiki/ISO_3166-2:IN"
states = {key: None for key in state_list}

try:
    # Checking if the request was successful 
    page = requests.get(url,timeout=10) # adding a time-out to prevent indefinite hanging
    page.raise_for_status() 
    print(f"Request Successful. Status code: {page.status_code}") 
    print('\n')
    
    # Organizing the HTML output
    soup = BeautifulSoup(page.content, 'lxml')
    table = soup.find_all("table", { 'class': 'wikitable'})
    data_list = table[0].find_all("tr")
    for ent in data_list[1:]:
        row_data= ent.find_all("td")
        d1,d2 = row_data[0:2]
        d1 = d1.text.replace('\n',"")[3:]
        d2 = d2.text.replace('\n',"")
        d2 = unidecode(d2).lower()
        if d2 in states.keys():
            states[d2]=d1
        if d2 == 'puducherry (pondicherry)': 
            d2 = d2[:-14]
            display(d2)
            states[d2]=d1
    display(states)
# Error messages in case the request was not successful 
except requests.exceptions.Timeout:
    print("The request timed out. Please check your network or try again later.")
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_er}.")
except requests.exceptions.ConnectionError as con_err:
    print(f"A connection error occurred: {con_err}.")
except ValueError as val_err:
    print(f"Value error: {val_err}.")
# Out:
# Request Successful. Status code: 200
# 'puducherry'
# {'arunachal pradesh': 'AR',
#  'jammu and kashmir': 'JK',
#  'andhra pradesh': 'AP',
#  'telangana': 'TS',
#  'manipur': 'MN',
#  'madhya pradesh': 'MP',
#  'haryana': 'HR',
#  'gujarat': 'GJ',
#  'sikkim': 'SK',
#  'himachal pradesh': 'HP',
#  'delhi': 'DL',
#  'punjab': 'PB',
#  'karnataka': 'KA',
#  'maharashtra': 'MH',
#  'odisha': 'OD',
#  'rajasthan': 'RJ',
#  'chandigarh': 'CH',
#  'kerala': 'KL',
#  'chhattisgarh': 'CG',
#  'tripura': 'TR',
#  'mizoram': 'MZ',
#  'assam': 'AS',
#  'meghalaya': 'ML',
#  'tamil nadu': 'TN',
#  'west bengal': 'WB',
#  'uttarakhand': 'UK',
#  'uttar pradesh': 'UP',
#  'puducherry': 'PY',
#  'bihar': 'BR',
#  'jharkhand': 'JH',
#  'nagaland': 'NL'}

# %%
# Creating a weather dictionary
weather = {}
weather["City"] = city_list
weather["Temperature"] = []
weather["Pressure"]=[]
weather["Humidity"]=[]
weather["Wind"] = []
weather["Precipitation"] = []
weather["Clouds"] = []
weather["Sunshine"]=[]

# Obtaining the weather information
try:
    for key, value in city_dict.items():
        stt = states[key]
        for i in value:
            # Make the request to obtain the longitude and latitude
            query = 'q='+i+','+stt+',IN' 
            response=requests.get('http://api.openweathermap.org/geo/1.0/direct?'+query+'&APPID='+api_key) 
            response.raise_for_status() # Check for errors
            loc_info = response.json()
            lat = loc_info[0]['lat']
            lon = loc_info[0]['lon']
            qlat = 'lat='+str(lat)
            qlon = 'lon='+str(lon)
        
            # Make the request to obtain weather information
            response1 = requests.get('https://history.openweathermap.org/data/2.5/aggregated/month?month=1&'+qlat+'&'+qlon+'&appid='+api_key)
            weather_info = response1.json()
        
            # Store weather information in dictionary, if missing enter "NONE"
            if "temp" in weather_info['result']:
                weather["Temperature"].append(weather_info['result']['temp']['mean'])
            else: 
                weather["Temperature"].append("NONE")
            if "wind" in weather_info['result']:
                weather["Wind"].append(weather_info['result']['wind']['mean'])
            else:
                weather["Wind"].append("NONE")
            if "precipitation" in weather_info['result']:
                weather["Precipitation"].append(weather_info['result']['precipitation']['mean'])
            else:
                weather["Precipitation"].append("NONE")
            if "pressure" in weather_info['result']:
                weather["Pressure"].append(weather_info['result']['pressure']['mean'])
            else: 
                weather["Pressure"].append("NONE") 
            if "humidity" in weather_info['result']:
                weather["Humidity"].append(weather_info['result']['humidity']['mean'])
            else: 
                weather["Humidity"].append("NONE")
            if "clouds" in weather_info['result']:
                weather["Clouds"].append(weather_info['result']['clouds']['mean'])
            else: 
                weather["Clouds"].append("NONE") 
            if "sunshine_hours" in weather_info['result']:
                weather["Sunshine"].append(weather_info['result']['sunshine_hours'])
            else: 
                weather["Sunshine"].append("NONE") 
            display(weather)
     
    # Create Data Frame
    df_weather= pd.DataFrame.from_dict(weather)
    with pd.option_context('display.max_rows', None,
                           'display.max_columns', None,
                           'display.precision', 3
                          ):
        display(df_weather)
        
# Error messages in case the request was not successful or an other error occurred
except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
# Out:
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89],
#  'Pressure': [1011.14],
#  'Humidity': [71.51],
#  'Wind': [1.43],
#  'Precipitation': [0.02],
#  'Clouds': [32.16],
#  'Sunshine': [98.15]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89, 271.41],
#  'Pressure': [1011.14, 911.42],
#  'Humidity': [71.51, 70.54],
#  'Wind': [1.43, 0.97],
#  'Precipitation': [0.02, 0.01],
#  'Clouds': [32.16, 45.52],
#  'Sunshine': [98.15, 115]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89, 271.41, 295.67],
#  'Pressure': [1011.14, 911.42, 1001.61],
#  'Humidity': [71.51, 70.54, 74.46],
#  'Wind': [1.43, 0.97, 2.3],
#  'Precipitation': [0.02, 0.01, 0.02],
#  'Clouds': [32.16, 45.52, 36.91],
#  'Sunshine': [98.15, 115, 127]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89, 271.41, 295.67, 296.25],
#  'Pressure': [1011.14, 911.42, 1001.61, 1003.4],
#  'Humidity': [71.51, 70.54, 74.46, 71.12],
#  'Wind': [1.43, 0.97, 2.3, 2.44],
#  'Precipitation': [0.02, 0.01, 0.02, 0.01],
#  'Clouds': [32.16, 45.52, 36.91, 29.62],
#  'Sunshine': [98.15, 115, 127, 120.15]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89, 271.41, 295.67, 296.25, 296.59],
#  'Pressure': [1011.14, 911.42, 1001.61, 1003.4, 991.01],
#  'Humidity': [71.51, 70.54, 74.46, 71.12, 60.59],
#  'Wind': [1.43, 0.97, 2.3, 2.44, 3.31],
#  'Precipitation': [0.02, 0.01, 0.02, 0.01, 0.01],
#  'Clouds': [32.16, 45.52, 36.91, 29.62, 30.42],
#  'Sunshine': [98.15, 115, 127, 120.15, 168.85]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89, 271.41, 295.67, 296.25, 296.59, 296.64],
#  'Pressure': [1011.14, 911.42, 1001.61, 1003.4, 991.01, 1016.04],
#  'Humidity': [71.51, 70.54, 74.46, 71.12, 60.59, 76.8],
#  'Wind': [1.43, 0.97, 2.3, 2.44, 3.31, 2.59],
#  'Precipitation': [0.02, 0.01, 0.02, 0.01, 0.01, 0],
#  'Clouds': [32.16, 45.52, 36.91, 29.62, 30.42, 23.05],
#  'Sunshine': [98.15, 115, 127, 120.15, 168.85, 135]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89, 271.41, 295.67, 296.25, 296.59, 296.64, 296.9],
#  'Pressure': [1011.14, 911.42, 1001.61, 1003.4, 991.01, 1016.04, 1015.41],
#  'Humidity': [71.51, 70.54, 74.46, 71.12, 60.59, 76.8, 74.82],
#  'Wind': [1.43, 0.97, 2.3, 2.44, 3.31, 2.59, 1.93],
#  'Precipitation': [0.02, 0.01, 0.02, 0.01, 0.01, 0, 0.01],
#  'Clouds': [32.16, 45.52, 36.91, 29.62, 30.42, 23.05, 26.2],
#  'Sunshine': [98.15, 115, 127, 120.15, 168.85, 135, 105.15]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89, 271.41, 295.67, 296.25, 296.59, 296.64, 296.9, 296.9],
#  'Pressure': [1011.14,
#   911.42,
#   1001.61,
#   1003.4,
#   991.01,
#   1016.04,
#   1015.41,
#   1015.41],
#  'Humidity': [71.51, 70.54, 74.46, 71.12, 60.59, 76.8, 74.82, 74.82],
#  'Wind': [1.43, 0.97, 2.3, 2.44, 3.31, 2.59, 1.93, 1.93],
#  'Precipitation': [0.02, 0.01, 0.02, 0.01, 0.01, 0, 0.01, 0.01],
#  'Clouds': [32.16, 45.52, 36.91, 29.62, 30.42, 23.05, 26.2, 26.2],
#  'Sunshine': [98.15, 115, 127, 120.15, 168.85, 135, 105.15, 105.15]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89,
#   271.41,
#   295.67,
#   296.25,
#   296.59,
#   296.64,
#   296.9,
#   296.9,
#   297],
#  'Pressure': [1011.14,
#   911.42,
#   1001.61,
#   1003.4,
#   991.01,
#   1016.04,
#   1015.41,
#   1015.41,
#   1017.74],
#  'Humidity': [71.51, 70.54, 74.46, 71.12, 60.59, 76.8, 74.82, 74.82, 73.04],
#  'Wind': [1.43, 0.97, 2.3, 2.44, 3.31, 2.59, 1.93, 1.93, 2.62],
#  'Precipitation': [0.02, 0.01, 0.02, 0.01, 0.01, 0, 0.01, 0.01, 0.01],
#  'Clouds': [32.16, 45.52, 36.91, 29.62, 30.42, 23.05, 26.2, 26.2, 20.03],
#  'Sunshine': [98.15, 115, 127, 120.15, 168.85, 135, 105.15, 105.15, 159.31]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89,
#   271.41,
#   295.67,
#   296.25,
#   296.59,
#   296.64,
#   296.9,
#   296.9,
#   297,
#   295.38],
#  'Pressure': [1011.14,
#   911.42,
#   1001.61,
#   1003.4,
#   991.01,
#   1016.04,
#   1015.41,
#   1015.41,
#   1017.74,
#   999.15],
#  'Humidity': [71.51,
#   70.54,
#   74.46,
#   71.12,
#   60.59,
#   76.8,
#   74.82,
#   74.82,
#   73.04,
#   76.57],
#  'Wind': [1.43, 0.97, 2.3, 2.44, 3.31, 2.59, 1.93, 1.93, 2.62, 2.01],
#  'Precipitation': [0.02, 0.01, 0.02, 0.01, 0.01, 0, 0.01, 0.01, 0.01, 0.01],
#  'Clouds': [32.16,
#   45.52,
#   36.91,
#   29.62,
#   30.42,
#   23.05,
#   26.2,
#   26.2,
#   20.03,
#   29.48],
#  'Sunshine': [98.15,
#   115,
#   127,
#   120.15,
#   168.85,
#   135,
#   105.15,
#   105.15,
#   159.31,
#   88.54]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89,
#   271.41,
#   295.67,
#   296.25,
#   296.59,
#   296.64,
#   296.9,
#   296.9,
#   297,
#   295.38,
#   295.31],
#  'Pressure': [1011.14,
#   911.42,
#   1001.61,
#   1003.4,
#   991.01,
#   1016.04,
#   1015.41,
#   1015.41,
#   1017.74,
#   999.15,
#   1015.12],
#  'Humidity': [71.51,
#   70.54,
#   74.46,
#   71.12,
#   60.59,
#   76.8,
#   74.82,
#   74.82,
#   73.04,
#   76.57,
#   61.22],
#  'Wind': [1.43, 0.97, 2.3, 2.44, 3.31, 2.59, 1.93, 1.93, 2.62, 2.01, 2.4],
#  'Precipitation': [0.02,
#   0.01,
#   0.02,
#   0.01,
#   0.01,
#   0,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01],
#  'Clouds': [32.16,
#   45.52,
#   36.91,
#   29.62,
#   30.42,
#   23.05,
#   26.2,
#   26.2,
#   20.03,
#   29.48,
#   22.98],
#  'Sunshine': [98.15,
#   115,
#   127,
#   120.15,
#   168.85,
#   135,
#   105.15,
#   105.15,
#   159.31,
#   88.54,
#   146.08]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
# ...
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89,
#   271.41,
#   295.67,
#   296.25,
#   296.59,
#   296.64,
#   296.9,
#   296.9,
#   297,
#   295.38,
#   295.31,
#   285.9,
#   289.46,
#   288.88,
#   289.46,
#   290.38,
#   287.81,
#   289.13,
#   288.88,
#   289.39,
#   290.2,
#   289.62,
#   290.24,
#   289.05,
#   288.75,
#   290.39,
#   290.39,
#   285.58],
#  'Pressure': [1011.14,
#   911.42,
#   1001.61,
#   1003.4,
#   991.01,
#   1016.04,
#   1015.41,
#   1015.41,
#   1017.74,
#   999.15,
#   1015.12,
#   979.83,
#   1001.08,
#   1002.47,
#   1001.08,
#   994.44,
#   1010.75,
#   996.34,
#   1002.47,
#   1000.66,
#   1000.56,
#   1000.95,
#   997.6,
#   994.05,
#   1002.71,
#   996.8,
#   996.8,
#   999.9],
#  'Humidity': [71.51,
#   70.54,
#   74.46,
#   71.12,
#   60.59,
#   76.8,
#   74.82,
#   74.82,
#   73.04,
#   76.57,
#   61.22,
#   75.23,
#   62.51,
#   63.18,
#   62.51,
#   53.54,
#   64.56,
#   59.29,
#   63.18,
#   59.45,
#   55.76,
#   63.04,
#   55.82,
#   59.36,
#   65.25,
#   59.83,
#   59.83,
#   67.29],
#  'Wind': [1.43,
#   0.97,
#   2.3,
#   2.44,
#   3.31,
#   2.59,
#   1.93,
#   1.93,
#   2.62,
#   2.01,
#   2.4,
#   1.25,
#   2.28,
#   1.93,
#   2.28,
#   2.95,
#   2.05,
#   1.95,
#   1.93,
#   2.08,
#   2.54,
#   2.08,
#   2.55,
#   2.21,
#   1.79,
#   2.46,
#   2.46,
#   2.49],
#  'Precipitation': [0.02,
#   0.01,
#   0.02,
#   0.01,
#   0.01,
#   0,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.04,
#   0.01,
#   0,
#   0.01,
#   0.02,
#   0.04,
#   0.03,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.03,
#   0,
#   0,
#   0.04],
#  'Clouds': [32.16,
#   45.52,
#   36.91,
#   29.62,
#   30.42,
#   23.05,
#   26.2,
#   26.2,
#   20.03,
#   29.48,
#   22.98,
#   26.31,
#   16.61,
#   17.96,
#   16.61,
#   10.46,
#   15.02,
#   15.61,
#   17.96,
#   15.14,
#   12.37,
#   16.91,
#   12.02,
#   14.74,
#   22.28,
#   12.76,
#   12.76,
#   25.62],
#  'Sunshine': [98.15,
#   115,
#   127,
#   120.15,
#   168.85,
#   135,
#   105.15,
#   105.15,
#   159.31,
#   88.54,
#   146.08,
#   91.38,
#   218.15,
#   214.85,
#   218.15,
#   254.62,
#   223.92,
#   243.77,
#   214.85,
#   243.46,
#   242.46,
#   217.54,
#   241.69,
#   245.08,
#   209,
#   229.23,
#   229.23,
#   200.46]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89,
#   271.41,
#   295.67,
#   296.25,
#   296.59,
#   296.64,
#   296.9,
#   296.9,
#   297,
#   295.38,
#   295.31,
#   285.9,
#   289.46,
#   288.88,
#   289.46,
#   290.38,
#   287.81,
#   289.13,
#   288.88,
#   289.39,
#   290.2,
#   289.62,
#   290.24,
#   289.05,
#   288.75,
#   290.39,
#   290.39,
#   285.58,
#   286.76],
#  'Pressure': [1011.14,
#   911.42,
#   1001.61,
#   1003.4,
#   991.01,
#   1016.04,
#   1015.41,
#   1015.41,
#   1017.74,
#   999.15,
#   1015.12,
#   979.83,
#   1001.08,
#   1002.47,
#   1001.08,
#   994.44,
#   1010.75,
#   996.34,
#   1002.47,
#   1000.66,
#   1000.56,
#   1000.95,
#   997.6,
#   994.05,
#   1002.71,
#   996.8,
#   996.8,
#   999.9,
#   1011.45],
#  'Humidity': [71.51,
#   70.54,
#   74.46,
#   71.12,
#   60.59,
#   76.8,
#   74.82,
#   74.82,
#   73.04,
#   76.57,
#   61.22,
#   75.23,
#   62.51,
#   63.18,
#   62.51,
#   53.54,
#   64.56,
#   59.29,
#   63.18,
#   59.45,
#   55.76,
#   63.04,
#   55.82,
#   59.36,
#   65.25,
#   59.83,
#   59.83,
#   67.29,
#   61.16],
#  'Wind': [1.43,
#   0.97,
#   2.3,
#   2.44,
#   3.31,
#   2.59,
#   1.93,
#   1.93,
#   2.62,
#   2.01,
#   2.4,
#   1.25,
#   2.28,
#   1.93,
#   2.28,
#   2.95,
#   2.05,
#   1.95,
#   1.93,
#   2.08,
#   2.54,
#   2.08,
#   2.55,
#   2.21,
#   1.79,
#   2.46,
#   2.46,
#   2.49,
#   2.17],
#  'Precipitation': [0.02,
#   0.01,
#   0.02,
#   0.01,
#   0.01,
#   0,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.04,
#   0.01,
#   0,
#   0.01,
#   0.02,
#   0.04,
#   0.03,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.03,
#   0,
#   0,
#   0.04,
#   0.01],
#  'Clouds': [32.16,
#   45.52,
#   36.91,
#   29.62,
#   30.42,
#   23.05,
#   26.2,
#   26.2,
#   20.03,
#   29.48,
#   22.98,
#   26.31,
#   16.61,
#   17.96,
#   16.61,
#   10.46,
#   15.02,
#   15.61,
#   17.96,
#   15.14,
#   12.37,
#   16.91,
#   12.02,
#   14.74,
#   22.28,
#   12.76,
#   12.76,
#   25.62,
#   20.58],
#  'Sunshine': [98.15,
#   115,
#   127,
#   120.15,
#   168.85,
#   135,
#   105.15,
#   105.15,
#   159.31,
#   88.54,
#   146.08,
#   91.38,
#   218.15,
#   214.85,
#   218.15,
#   254.62,
#   223.92,
#   243.77,
#   214.85,
#   243.46,
#   242.46,
#   217.54,
#   241.69,
#   245.08,
#   209,
#   229.23,
#   229.23,
#   200.46,
#   216]}
# {'City': ['naharlagun',
#   'srinagar',
#   'chittoor',
#   'kadapa',
#   'anantapur',
#   'visakhapatnam',
#   'amaravati',
#   'vijayawada',
#   'rajamahendravaram',
#   'tirupati',
#   'hyderabad',
#   'imphal',
#   'mandideep',
#   'satna',
#   'bhopal',
#   'ratlam',
#   'gwalior',
#   'katni',
#   'maihar',
#   'damoh',
#   'dewas',
#   'jabalpur',
#   'ujjain',
#   'sagar',
#   'singrauli',
#   'pithampur',
#   'indore',
#   'ambala',
#   'sirsa',
#   'palwal',
#   'kurukshetra',
#   'ballabgarh',
#   'manesar',
#   'narnaul',
#   'gurugram',
#   'karnal',
#   'bahadurgarh',
#   'rohtak',
#   'kaithal',
#   'sonipat',
#   'mandikhera',
#   'faridabad',
#   'hisar',
#   'yamunanagar',
#   'charkhi_dadri',
#   'jind',
#   'panipat',
#   'bhiwani',
#   'panchkula',
#   'fatehabad',
#   'dharuhera',
#   'ankleshwar',
#   'gandhinagar',
#   'surat',
#   'vapi',
#   'vatva',
#   'ahmedabad',
#   'nandesari',
#   'gangtok',
#   'baddi',
#   'delhi',
#   'ludhiana',
#   'bathinda',
#   'mandi_gobindgarh',
#   'khanna',
#   'rupnagar',
#   'jalandhar',
#   'amritsar',
#   'patiala',
#   'mysuru',
#   'yadgir',
#   'kolar',
#   'koppal',
#   'bidar',
#   'vijayapura',
#   'gadag',
#   'mangalore',
#   'kalaburagi',
#   'hubballi',
#   'udupi',
#   'belgaum',
#   'madikeri',
#   'haveri',
#   'tumakuru',
#   'bengaluru',
#   'dharwad',
#   'hassan',
#   'shivamogga',
#   'chikkamagaluru',
#   'chamarajanagar',
#   'chikkaballapur',
#   'bagalkot',
#   'davanagere',
#   'ramanagara',
#   'raichur',
#   'karwar',
#   'latur',
#   'kalyan',
#   'sangli',
#   'dhule',
#   'bhiwandi',
#   'virar',
#   'kolhapur',
#   'nagpur',
#   'chandrapur',
#   'pune',
#   'jalgaon',
#   'solapur',
#   'ulhasnagar',
#   'amravati',
#   'parbhani',
#   'badlapur',
#   'akola',
#   'boisar',
#   'mumbai',
#   'jalna',
#   'nashik',
#   'belapur',
#   'malegaon',
#   'thane',
#   'navi_mumbai',
#   'mahad',
#   'nanded',
#   'baripada',
#   'bileipada',
#   'angul',
#   'tensa',
#   'cuttack',
#   'balasore',
#   'keonjhar',
#   'rairangpur',
#   'talcher',
#   'byasanagar',
#   'suakati',
#   'rourkela',
#   'nayagarh',
#   'barbil',
#   'brajrajnagar',
#   'sirohi',
#   'baran',
#   'banswara',
#   'hanumangarh',
#   'bharatpur',
#   'bikaner',
#   'jalore',
#   'bhiwadi',
#   'sikar',
#   'karauli',
#   'bhilwara',
#   'alwar',
#   'bundi',
#   'dausa',
#   'chittorgarh',
#   'barmer',
#   'jaipur',
#   'jaisalmer',
#   'pratapgarh',
#   'sawai_madhopur',
#   'jhalawar',
#   'jhunjhunu',
#   'nagaur',
#   'ajmer',
#   'rajsamand',
#   'jodhpur',
#   'sri_ganganagar',
#   'pali',
#   'kota',
#   'dholpur',
#   'dungarpur',
#   'tonk',
#   'churu',
#   'udaipur',
#   'chandigarh',
#   'thiruvananthapuram',
#   'thrissur',
#   'kozhikode',
#   'kollam',
#   'kannur',
#   'eloor',
#   'ernakulam',
#   'kochi',
#   'bhilai',
#   'chhal',
#   'milupara',
#   'bilaspur',
#   'raipur',
#   'tumidih',
#   'kunjemura',
#   'korba',
#   'aizawl',
#   'silchar',
#   'nalbari',
#   'guwahati',
#   'nagaon',
#   'sivasagar',
#   'byrnihat',
#   'shillong',
#   'tiruchirappalli',
#   'nagapattinam',
#   'coimbatore',
#   'vellore',
#   'ranipet',
#   'dindigul',
#   'tirupur',
#   'ooty',
#   'kanchipuram',
#   'tirunelveli',
#   'chennai',
#   'gummidipoondi',
#   'perundurai',
#   'thanjavur',
#   'cuddalore',
#   'karur',
#   'thoothukudi',
#   'pudukottai',
#   'ariyalur',
#   'salem',
#   'madurai',
#   'ramanathapuram',
#   'virudhunagar',
#   'hosur',
#   'palkalaiperur',
#   'chengalpattu',
#   'kolkata',
#   'haldia',
#   'durgapur',
#   'siliguri',
#   'asansol',
#   'howrah',
#   'barrackpore',
#   'kashipur',
#   'rishikesh',
#   'dehradun',
#   'agra',
#   'prayagraj',
#   'meerut',
#   'jhansi',
#   'greater_noida',
#   'kanpur',
#   'bulandshahr',
#   'lucknow',
#   'firozabad',
#   'moradabad',
#   'hapur',
#   'vrindavan',
#   'ghaziabad',
#   'bareilly',
#   'noida',
#   'varanasi',
#   'muzaffarnagar',
#   'gorakhpur',
#   'khurja',
#   'baghpat',
#   'puducherry',
#   'rajgir',
#   'araria',
#   'bettiah',
#   'begusarai',
#   'katihar',
#   'saharsa',
#   'samastipur',
#   'motihari',
#   'muzaffarpur',
#   'bhagalpur',
#   'buxar',
#   'darbhanga',
#   'sasaram',
#   'bihar_sharif',
#   'purnia',
#   'manguraha',
#   'patna',
#   'arrah',
#   'hajipur',
#   'siwan',
#   'chhapra',
#   'kishanganj',
#   'munger',
#   'gaya',
#   'dhanbad',
#   'jorapokhar',
#   'pathardih',
#   'kohima'],
#  'Temperature': [288.89,
#   271.41,
#   295.67,
#   296.25,
#   296.59,
#   296.64,
#   296.9,
#   296.9,
#   297,
#   295.38,
#   295.31,
#   285.9,
#   289.46,
#   288.88,
#   289.46,
#   290.38,
#   287.81,
#   289.13,
#   288.88,
#   289.39,
#   290.2,
#   289.62,
#   290.24,
#   289.05,
#   288.75,
#   290.39,
#   290.39,
#   285.58,
#   286.76,
#   286.89],
#  'Pressure': [1011.14,
#   911.42,
#   1001.61,
#   1003.4,
#   991.01,
#   1016.04,
#   1015.41,
#   1015.41,
#   1017.74,
#   999.15,
#   1015.12,
#   979.83,
#   1001.08,
#   1002.47,
#   1001.08,
#   994.44,
#   1010.75,
#   996.34,
#   1002.47,
#   1000.66,
#   1000.56,
#   1000.95,
#   997.6,
#   994.05,
#   1002.71,
#   996.8,
#   996.8,
#   999.9,
#   1011.45,
#   1013.87],
#  'Humidity': [71.51,
#   70.54,
#   74.46,
#   71.12,
#   60.59,
#   76.8,
#   74.82,
#   74.82,
#   73.04,
#   76.57,
#   61.22,
#   75.23,
#   62.51,
#   63.18,
#   62.51,
#   53.54,
#   64.56,
#   59.29,
#   63.18,
#   59.45,
#   55.76,
#   63.04,
#   55.82,
#   59.36,
#   65.25,
#   59.83,
#   59.83,
#   67.29,
#   61.16,
#   70.21],
#  'Wind': [1.43,
#   0.97,
#   2.3,
#   2.44,
#   3.31,
#   2.59,
#   1.93,
#   1.93,
#   2.62,
#   2.01,
#   2.4,
#   1.25,
#   2.28,
#   1.93,
#   2.28,
#   2.95,
#   2.05,
#   1.95,
#   1.93,
#   2.08,
#   2.54,
#   2.08,
#   2.55,
#   2.21,
#   1.79,
#   2.46,
#   2.46,
#   2.49,
#   2.17,
#   2.44],
#  'Precipitation': [0.02,
#   0.01,
#   0.02,
#   0.01,
#   0.01,
#   0,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.04,
#   0.01,
#   0,
#   0.01,
#   0.02,
#   0.04,
#   0.03,
#   0.01,
#   0.01,
#   0.01,
#   0.01,
#   0.03,
#   0,
#   0,
#   0.04,
#   0.01,
#   0.01],
#  'Clouds': [32.16,
#   45.52,
#   36.91,
#   29.62,
#   30.42,
#   23.05,
#   26.2,
#   26.2,
#   20.03,
#   29.48,
#   22.98,
#   26.31,
#   16.61,
#   17.96,
#   16.61,
#   10.46,
#   15.02,
#   15.61,
#   17.96,
#   15.14,
#   12.37,
#   16.91,
#   12.02,
#   14.74,
#   22.28,
#   12.76,
#   12.76,
#   25.62,
#   20.58,
#   22.15],
#  'Sunshine': [98.15,
#   115,
#   127,
#   120.15,
#   168.85,
#   135,
#   105.15,
#   105.15,
#   159.31,
#   88.54,
#   146.08,
#   91.38,
#   218.15,
#   214.85,
#   218.15,
#   254.62,
#   223.92,
#   243.77,
#   214.85,
#   243.46,
#   242.46,
#   217.54,
#   241.69,
#   245.08,
#   209,
#   229.23,
#   229.23,
#   200.46,
#   216,
#   189.54]}

# %%
key = "gujarat"
value = city_dict["gujarat"]
stt = states[key]
for i in value:
    # Make the request to obtain the longitude and latitude
    query = 'q='+i+','+stt+',IN' 
    response=requests.get('http://api.openweathermap.org/geo/1.0/direct?'+query+'&APPID='+api_key) 
    response.raise_for_status() # Check for errors
    loc_info = response.json()
    if len(loc_info)==0:
        print("City "+i+" cannot be found through the api")
    else:
        lat = loc_info[0]['lat']
        lon = loc_info[0]['lon']
        qlat = 'lat='+str(lat)
        qlon = 'lon='+str(lon)
        display(qlat)
        display(qlon)
            
                       
    # Create Data Frame
   # df_weather= pd.DataFrame.from_dict(weather)
    #with pd.option_context('display.max_rows', None,
     #                      'display.max_columns', None,
      #                     'display.precision', 3
       #                   ):
       # display(df_weather)

# %%
response1 = requests.get('https://history.openweathermap.org/data/2.5/aggregated/month?month=1&'+qlat+'&'+qlon+'&appid='+api_key)
weather_info = response1.json()
display(weather_info)

# %%
# Make the request to obtain weather information
weather = {}
weather["City"] = city_list
weather["Temperature"] = []
weather["Pressure"]=[]
weather["Humidity"]=[]
weather["Wind"] = []
weather["Precipitation"] = []
weather["Clouds"] = []
weather["Sunshine"]=[]

# %%
# Store weather information in dictionary, if missing enter "NONE"
if "temp" in weather_info['result']:
    weather["Temperature"].append(weather_info['result']['temp']['mean'])
else: 
    weather["Temperature"].append("NONE")
if "wind" in weather_info['result']:
    weather["Wind"].append(weather_info['result']['wind']['mean'])
else:
    weather["Wind"].append("NONE")
if "precipitation" in weather_info['result']:
    weather["Precipitation"].append(weather_info['result']['precipitation']['mean'])
else:
    weather["Precipitation"].append("NONE")
if "pressure" in weather_info['result']:
    weather["Pressure"].append(weather_info['result']['pressure']['mean'])
else: 
    weather["Pressure"].append("NONE") 
if "humidity" in weather_info['result']:
    weather["Humidity"].append(weather_info['result']['humidity']['mean'])
else: 
    weather["Humidity"].append("NONE")
if "clouds" in weather_info['result']:
    weather["Clouds"].append(weather_info['result']['clouds']['mean'])
else: 
    weather["Clouds"].append("NONE") 
if "sunshine_hours" in weather_info['result']:
    weather["Sunshine"].append(weather_info['result']['sunshine_hours'])
else: 
    weather["Sunshine"].append("NONE") 
display(weather)

# Create Data Frame
#df_weather= pd.DataFrame.from_dict(weather)
#with pd.option_context('display.max_rows', None,
 #                      'display.max_columns', None,
  #                     'display.precision', 3
   #                    ):
    #display(df_weather)
